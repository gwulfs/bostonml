# %% [markdown]
# # Web Scraping and Machine Learning in Python

# %% [markdown]
# The following provides an example of how you can do some pretty sophisticated web scraping and machine learning analysis in Python with surprisingly little code! Here are some things that will be covered in this notebook:
# <ul>
# <li>IPython Notebooks</li>
# <li>Parsing HTML using [lxml](http://lxml.de/)</li>
# <li>Data manipulation and analysis in [pandas](http://pandas.pydata.org)</li>
# <li>Machine learning for classification: Multinomial Naive Bayes in [sklearn](http://scikit-learn.org)</li>
# </ul>
#
# What we're going to do here is we're going to see if we can teach our computer how to tell a Wall Street Journal article headline from a Gawker headline.
#
# Inspiration for this notebook/presentation was provided by [this](http://nbviewer.ipython.org/github/nealcaren/workshop_2014/blob/master/notebooks/6_Classification.ipynb) and [this](http://nbviewer.ipython.org/github/cs109/content/blob/master/HW3_solutions.ipynb). If you want to run this notebook, or one like it, it'll be helpful for you to check out [Anaconda](https://store.continuum.io/cshop/anaconda/)

# %%
from IPython.display import Image
Image("http://www.japantrendshop.com//img/goldstar/asimo-robot-suit-costume-newspaper-cosplay.JPG")

# %% [markdown]
# ## Get the Data!
# If we want our robot friend to develop a discerning taste for quality news, we're going to have to find him some examples. Lucky for us, Gawker and the Wall Street Journal both have websites.
# ### To the internet (with dev tools)!
# #### [Gawker](http://gawker.com)
# After poking around the gawker homepage with the help of developer tools(command + option + i will bring up the dev tools on a mac) and a chrome plugin, [XPath Helper](https://chrome.google.com/webstore/detail/xpath-helper/hgimnogjllphhhkhlmebbmlgjoejdpjl?hl=en) for Chrome, we can see that all the article titles can be grabbed with the xpath, `"//header/h1/a/text()"`. lxml lets us retrieve all the text that matches our xpath in this way:

# %%
from lxml import html 
x = html.parse('http://gawker.com')
titles = x.xpath('//header/h1/a/text()')
print "We got {} titles. Here are the first 5:".format(len(titles))
titles[:5]
# Out:
# We got 20 titles. Here are the first 5:
# ['Guy Jumps Over White House Fence, Punches a Secret Service Dog',
#  'Woman Sets Her Roommate on Fire Over a Thrown-Out Plate of Spaghetti',
#  'Wednesday Night TV Remembers Buying Its First Lincoln, Too',
#  'Which "Tech Couple" Is Spending Millions on a San Francisco Bunker?',
#  'This Week in Tabloids: Kardashian Pets Are Mysteriously Disappearing']

# %% [markdown]
# This page only has 20 titles on it. If we want to properly train our robot, we're going to need more examples. There's a "More Stories" button at the bottom of the page, which brings us to another, similarly structured, page with new titles and another "More Stories" button. To get more examples, we'll repeat the process above in a loop with each successive iteration hitting the page pointed to by the "More Stories" button. In order to figure out what tha link is, go do some more investigating! You can also just look at the code below.

# %%
headlines = x.xpath('//header/h1/a/text()')

# %%
# These are the xpaths we determined from snooping 
next_button_xpath = "//div[@class='row load-more']//a[contains(@href, 'startTime')]/@href"
headline_xpath = '//header/h1/a/text()'

# We'll use sleep to add some time in between requests
# so that we're not bombarding Gawker's server too hard. 
from time import sleep

# Now we'll fill this list of gawker titles by starting
# at the landing page and following "More Stories" links
# until we have a decent number of titles. 
gawker_titles = []
base_url = 'http://gawker.com/{}'
next_page = "http://gawker.com/"
while len(gawker_titles) < 2000 and next_page:
    dom = html.parse(next_page)
    headlines = dom.xpath(headline_xpath)
    print "Retrieved {} titles from url: {}".format(len(headlines), next_page)
    gawker_titles += headlines
    next_pages = dom.xpath(next_button_xpath)
    if next_pages: 
        next_page = base_url.format(next_pages[0]) 
    else:
        print "No next button found"
        next_page = None
    sleep(5)

# %%
with open('gawker_titles.txt', 'wb') as out:
    out.writelines(gawker_titles)
# with open('gawker_titles.txt') as f:
#     gawker_titles = f.readlines()
    
print "Holy smokes, we got {} Gawker headlines!".format(len(gawker_titles))

# %% [markdown]
# #### [Wall Street Journal](http://online.wsj.com/public/page/archive-2014-1-1.html)
# Now we'll do a similar thing with WSJ now. Here we notice that they have a section of the site where they have lists of archived articles for each day in the past year. There are links to the different archive dates all over the page, and we can see that the links are all of the same structure, just with different dates in the URL. All we have to do is iterate over a bunch of dates. I grabbed the articles from the first day of each month this year

# %%
wsj_url = "http://online.wsj.com/public/page/archive-2014-{}-1.html"
wsj_headline_xpath = "//h2/a/text()"
wsj_headlines = []
for i in range(1, 11): 
    dom = html.parse(wsj_url.format(i))
    titles = dom.xpath(wsj_headline_xpath)
    wsj_headlines += titles
    print "Retrieved {} WSJ headlines from url: {}".format(len(titles), wsj_url.format(i))
# Out:
# Retrieved 115 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-1-1.html
# Retrieved 22 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-2-1.html
# Retrieved 32 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-3-1.html
# Retrieved 275 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-4-1.html
# Retrieved 365 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-5-1.html
# Retrieved 111 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-6-1.html
# Retrieved 293 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-7-1.html
# Retrieved 284 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-8-1.html
# Retrieved 156 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-9-1.html
# Retrieved 386 WSJ headlines from url: http://online.wsj.com/public/page/archive-2014-10-1.html

# %%
with open('wsj_titles.txt', 'wb') as out:
    out.writelines(wsj_headlines)
# with open('wsj_titles.txt') as f:
#     wsj_headlines = f.readlines()
    
print "Jeez, Louise! We got {} WSJ headlines!".format(len(wsj_headlines))

# %%
from random import sample
print "Some WSJ Headlines"
print "------------------"
print "\n".join(sample(wsj_headlines, 10))
print
print "Some Gawker Headlines"
print "------------------"
print "\n".join(sample(gawker_titles, 10))
# Out:
# Some WSJ Headlines
# ------------------
# Bank of America Board Gives Chairman Job to Brian Moynihan
# Acuity Brands Profit Rises 22% on Sales Growth
# Oil Futures Sag on Record-High Inventories
# China Gives Microsoft 20 Days to Explain Problems
# Uruguay Asks Potential Pot Investors to Step Forward
# The Year in Oil
# U.K. Consumer Lending in July Highest Since 2008
# Authors Guild Met With DoJ to Seek Investigation Into Amazon's Practices
# Mise en Seine: Hollywood's French Obsession
# Deal to End Afghan Election Crisis on Verge of Collapse
#
# Some Gawker Headlines
# ------------------
# Two Possible Ebola Patients Quarantined in New York City:
# Bethenny Frankel Is Back to Terrorize
# The Burger King Tweet That Might Be the Saddest Tweet of All Time
# Buncha Snakes Died
# Jennifer Garner Gave Up Her Life of Streaking to Hire Goat Gardeners
# Political Conventions To Be More Easily Corrupted
# These Are the Creepy 4Chan Successors Behind Gamergate's Pathetic War
# ...

# %% [markdown]
# ### Here's a stupid, lizard-shaped word cloud of WSJ words

# %%
Image(filename="/Users/marcusway/Downloads/Cloud 2.png", height=400, width=400)

# %% [markdown]
# ### Here's a stupid, cat-shaped word cloud of Gawker words

# %%
Image(filename="/Users/marcusway/Downloads/Cloud 1.png", height=400, width=400)

# %% [markdown]
# Now we'll use pandas to build a data frame with two columns: "gawker", which contains a boolean value indicating whether the value in the "title" column came from Gawker's website.

# %%
import pandas as pd
gawk_records = [{'gawker': True, 'title': title} for title in gawker_titles]
wsj_records = [{'gawker': False, 'title': title} for title in wsj_headlines]
df = pd.DataFrame.from_records(gawk_records + wsj_records)
df.tail()
# Out:
#      gawker                                              title
# 2811  False  As Child Immigrants Await Fate, a Race for Cou...
# 2812  False                          The Band Goes Marching On
# 2813  False                     U.S. Office Sector Plods Ahead
# 2814  False                                       What's News—
# 2815  False                                       What's News—

# %% [markdown]
# ## Teach the Machine!

# %% [markdown]
# Now for some machine learning! The basic goal of machine learning is to learn some model or function that maps our inputs, or observations to outputs, or predictions. The model that we'll be building to make our predictions is known as Naive Bayes. Ultimately, what we want to determine is the probability that Bayes theorem. We have (or can compute by counting) the probability that any given word shows up in a Gawker title, or P(Word | Gawker). We want the probability that a bunch of words _is_ a  Gawker title, or P(Gawker | Words). The way that our robot will make predicitons is by using the formula,
#
# $$P(Gawker | Words) = P(Word_1|Gawker)*P(Word_2|Gawker)*..*P(Word_n | Gawker)*P(Gawker)$$
#
# where all of the probabilities on the right side of the equation are empirically determined from the text data. Luckily, instead of having to write all of the code to determine those probabilities ourselves, sklearn's CountVectorizer does all of the dirty work for us.

# %%
import numpy as np
from sklearn.feature_extraction.text import CountVectorizer
from sklearn import cross_validation, naive_bayes

# %%
# def make_xy(df, vectorizer=None):
#     #Your code here    
#     if vectorizer is None:
#         vectorizer = CountVectorizer(min_df=5, max_df=.3, ngram_range=(1,2))
#     X = vectorizer.fit_transform(df.title)
#     X = X.tocsc()  # some versions of sklearn return COO format
#     Y = df.gawker.values.astype(np.int)
#     return X, Y

# %%
vectorizer = CountVectorizer(min_df=5, max_df=.3, ngram_range=(1,2))
# X, Y = make_xy(df)
X = vectorizer.fit_transform(df.title)
X = X.tocsc()  # some versions of sklearn return COO format
Y = df.gawker.values.astype(np.int) # Need numbers instead of bools for

# %% [markdown]
# Now we have a data array, X, whose rows correspond to titles and whose columns correspond to words. So the value X[i,j] is the number of times word j shows up in article title i. Each row has a corresponding member in vector, Y. If the headline associated with X[i] came from Gawker, Y[i] == 1. Otherwise, Y[i] == 0. Now our data are in a format our robot will understand. What we'll do now is to split the data into a training dataset, which we'll use to teach the robot, and a test dataset, which we will use to see how well our robot has learned.

# %%
X_train, X_test, Y_train, Y_test = cross_validation.train_test_split(X,Y)

# %%
clf = naive_bayes.MultinomialNB(fit_prior=False, alpha=0.5)
clf.fit(X_train, Y_train)
# Out:
# MultinomialNB(alpha=0.5, class_prior=None, fit_prior=False)

# %% [markdown]
# ## Test the machine!

# %% [markdown]
# Now our robot has built a model. We'll see how good that model is by testing the accuracy of its predictions on articles it hasn't seen before. The accuracy metric reported below is simply the percentage of titles it classifies correctly.

# %%
print "Accuracy: %0.2f%%" % (100 * clf.score(X_test, Y_test))
# Out:
# Accuracy: 81.53%

# %% [markdown]
# Not bad for a machine! We can take a closer look at how the robot is making its predictions. Let's look at which words are the Gawkeriest and which ones are the Wall Street Journaliest.

# %%
import numpy as np
words = np.array(vectorizer.get_feature_names())

x = np.eye(X_test.shape[1])
probs = clf.predict_log_proba(x)[:, 0]
ind = np.argsort(probs)

good_words = words[ind[:10]]
bad_words = words[ind[-10:]]

good_prob = probs[ind[:10]]
bad_prob = probs[ind[-10:]]

print "Gawker words\t P(gawker| word)"
for w, p in zip(good_words, good_prob):
    print "%20s" % w, "%0.2f" % (1 - np.exp(p))
    
print "WSJ words\t P(gawker | word)"
for w, p in zip(bad_words, bad_prob):
    print "%20s" % w, "%0.2f" % (1 - np.exp(p))
# Out:
# Gawker words	 P(gawker| word)
#            gamergate 0.99
#                these 0.99
#              are the 0.99
#    successors behind 0.99
#   gamergate pathetic 0.99
#             pathetic 0.99
#         pathetic war 0.99
#         creepy 4chan 0.99
#               creepy 0.99
#     4chan successors 0.99
# WSJ words	 P(gawker | word)
#               profit 0.05
#              ukraine 0.04
#                  oil 0.04
#                rises 0.04
#               russia 0.04
#            what news 0.03
#                  ipo 0.03
#        manufacturing 0.03
#                sales 0.03
#                china 0.02

# %% [markdown]
# You might be complaining that our robot should do better. But some titles can be tough. Would you have classified this mis-predicted article titles correctly?

# %%
#Your code here
prob = clf.predict_proba(X)[:, 0]
predict = clf.predict(X)

bad_wsj = np.argsort(prob[Y == 0])[:5]
bad_gawker = np.argsort(prob[Y == 1])[-5:]

print "Mis-predicted WSJ quotes"
print '---------------------------'
for row in bad_wsj:
    print df[Y == 0].title.irow(row)
    print

print
print "Mis-predicted Gawker quotes"
print '--------------------------'
for row in bad_gawker:
    print df[Y == 1].title.irow(row)
    print
# Out:
# Mis-predicted WSJ quotes
# ---------------------------
# U.S. Pursues Contacts of Ebola Patient in Texas
#
# Boy Bands, Beware These New Kids
#
# Stockholm Patient Does Not Have Ebola
#
# Photo of the Week
#
# Donald Sterling Tape Was Made in Presence of Woman's Family Member
#
#
# Mis-predicted Gawker quotes
# --------------------------
# South Carolina Governor Says CEOs Love the Confederate Flag
#
# Ratings Screwup Ruins ABC News' Victory Against Brian Williams
#
# New York's Scummiest Slumlord Lives in a $1.2 Million Suburban Mansion
#
# Airbnb Investors Finance Smear Campaign as Reward for Favorable Law
#
# Hong Kong Protests Turn Violent Once Again in Lead-Up to Talks

# %% [markdown]
# Make your own headline and see if it belongs in Gawker or WSJ!

# %%
probs = clf.predict_proba(vectorizer.transform(["Your fucking title here"]))
print "P(gawker) = {}".format(probs[0][1])
# Out:
# P(gawker) = 0.99841598388
